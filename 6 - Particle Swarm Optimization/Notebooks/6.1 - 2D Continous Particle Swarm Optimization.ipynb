# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Problem Description
#
# Particle Swarm Optimization: it's given a particular Objective Function to optimize. The function is "f(x,y) = x^2 + y^2", which has its global best in "f(0,0) = 0".

# %% [markdown]
# ## Class "Particle"
# It contains all the salient informations about a Particle of the Swarm.

# %%
class Particle:
    def __init__(self, id, bounds):
        self.id = id

        self.positions = list()
        start_x = np.random.uniform(low=bounds[0][0], high=bounds[0][1])
        start_y = np.random.uniform(low=bounds[1][0], high=bounds[1][1])
        self.positions.append([start_x,start_y])

        self.velocities = list()
        start_vx = np.random.uniform(low=bounds[0][0], high=bounds[0][1])
        start_vy = np.random.uniform(low=bounds[1][0], high=bounds[1][1])
        self.velocities.append([start_vx,start_vy])

        self.best_value = np.inf
        self.best_idx = None

        self.values = list()
        eval_function(self)

# %% [markdown]
# # Particle Swarm Algorithm

# %% [markdown]
# ## Support Functions

# %%
# Evaluates the last position reached by the Particle.
def eval_function(p):
    last = len(p.positions)-1
    x = p.positions[last][0]
    y = p.positions[last][1]

    value = x**2 + y**2
    p.values.append(value)

    # Observation: for each Particle we memorize its "Personal Best Value" yet reached.
    # If we found a new "Personal Best", it gets updated.
    if value < p.best_value:
        p.best_value = value
        p.best_idx = last

# %%
# Executes a move for a Particle.
def move_particle(p, omega, l1, l2, p_best, g_best, bounds):
    p_best = np.array(p_best)
    g_best = np.array(g_best)

    s0 = np.array(p.positions[len(p.positions)-1])
    v0 = np.array(p.velocities[len(p.velocities)-1])

    v1 = omega*v0 + l1*(p_best - s0) + l2*(g_best - s0)
    p.velocities.append(v1)

    s1 = list(v1 + s0)

    # Observation: if the particle exceeds the problem's bounds, his position is resetted to a random position within the bounds.
    if not (bounds[0][0] <= s1[0] <= bounds[0][1]):
        s1[0] = np.random.uniform(low=bounds[0][0], high=bounds[0][1])
        

    if not (bounds[1][0] <= s1[1] <= bounds[1][1]):
        s1[1] = np.random.uniform(low=bounds[1][0], high=bounds[1][1])
    
    p.positions.append(s1)

# %% [markdown]
# ## Principal Function

# %%
def particle_swarm_optimization(bounds, n_particles, n_iterations, omega):
    print("*** *************************** ***")
    print("*** PARTICLE SWARM OPTIMIZATION ***")
    print("*** *************************** ***\n")
    # Initializing the Swarm
    particle_swarm = list()
    for i in range(0, n_particles):
        p = Particle(i, bounds)
        particle_swarm.append(p)
    
    # Initializing the "Global Best" Informations
    g_best_value = np.inf
    g_best = None
    chief_particle = None
    
    # Principal Cycle
    for it in range(0, n_iterations):
        particles_best = list()
        
        # (If necesssary) update the "Global Best".
        for p in particle_swarm:
            particles_best.append(p.positions[p.best_idx])
            value = p.best_value
            if value < g_best_value:
                g_best_value = value
                g_best = p.positions[p.best_idx]
                chief_particle = p.id
        
        # Actual Iteration's salient Informations.
        print("ITERATION: " + str(it+1) + " -> Global Best Value = " + str(g_best_value))
        data = pd.DataFrame(index = ["Particle %d" % i for i in range(0, n_particles)],
                            columns=['atm_position', 'atm_value', 'personal_best', 'chief'])
        
        for p in particle_swarm:
            row = "Particle " + str(p.id)
            if p.id == chief_particle:
                data.loc[row] = [p.positions[len(p.positions)-1], p.values[len(p.values)-1], p.best_value, "CHIEF"]
            else:
                data.loc[row] = [p.positions[len(p.positions)-1], p.values[len(p.values)-1], p.best_value, "X"]  
        print(data)
        print()

        # Time to move for the Particles!
        l1 = np.random.rand()
        l2 = np.random.rand()
        for i in range(0, len(particle_swarm)):
            particle = particle_swarm[i]
            p_best = particles_best[i]

            move_particle(particle, omega, l1, l2, p_best, g_best, bounds)
            eval_function(particle)
    
    print("*** SEARCH IS OVER! ***")

# %% [markdown]
# # CODE'S TEST SECTION

# %%
# Parameters Settings
bounds = [[-10.0, 10.0], [-10.0, 10.0]]     # x in [-10, 10], y in [-10, 10]
n_particles = 10
n_iterations = 20
omega = 0.7

# %%
particle_swarm_optimization(bounds, n_particles, n_iterations, omega)
# Out:
# *** *************************** ***
# *** PARTICLE SWARM OPTIMIZATION ***
# *** *************************** ***
#
# ITERATION: 1 -> Global Best Value = 4.491585501100242
#                                          atm_position   atm_value  \
# Particle 0     [-9.07972458333145, 6.446533355727205]  123.999191
# Particle 1   [8.484749008061076, 0.23994381888083716]   72.048539
# Particle 2   [-9.462849781032789, -7.757129374600855]  149.718582
# Particle 3    [9.182310372283581, -8.336510760926776]  153.812235
# Particle 4    [4.418798632638307, 0.4211423654639468]   19.703142
# Particle 5     [6.789314423870135, 8.079664265186171]  111.375765
# Particle 6  [1.6150960443468598, -1.3722427877877035]    4.491586
# Particle 7   [-3.757547897560114, 2.6128029442985774]   20.945905
# Particle 8     [9.12675620018727, -5.895299907232343]   118.05224
# Particle 9   [-3.489537942135968, -9.009549429393047]   93.348856
#
#            personal_best  chief
# Particle 0    123.999191      X
# Particle 1     72.048539      X
# Particle 2    149.718582      X
# Particle 3    153.812235      X
# Particle 4     19.703142      X
# Particle 5    111.375765      X
# Particle 6      4.491586  CHIEF
# Particle 7     20.945905      X
# Particle 8     118.05224      X
# Particle 9     93.348856      X
#
# ITERATION: 2 -> Global Best Value = 0.25515758734485183
#                                           atm_position  atm_value  \
# Particle 0     [0.9491513841925805, 4.940852067923045]  25.312908
# Particle 1    [3.245992946272583, -0.9971995144753321]  11.530877
# Particle 2    [-8.668371297398572, -9.656610114175344]  168.39078
# Particle 3     [9.753057113933334, -2.011273519786009]  99.167344
# Particle 4      [1.936250493035772, 5.950511079772571]  39.157648
# Particle 5    [4.3954979579118305, 1.8872494018926478]  22.882113
# Particle 6  [-0.3878271002468727, -0.3236475361546167]   0.255158
# Particle 7    [-4.243889436208061, 5.6359057852445185]  49.774032
# Particle 8   [-1.1836643808608045, -9.765189743507422]  96.759992
# Particle 9    [-1.1111875134593925, -9.03251862664243]   82.82113
#
#            personal_best  chief
# Particle 0     25.312908      X
# Particle 1     11.530877      X
# Particle 2    149.718582      X
# Particle 3     99.167344      X
# Particle 4     19.703142      X
# Particle 5     22.882113      X
# Particle 6      0.255158  CHIEF
# Particle 7     20.945905      X
# Particle 8     96.759992      X
# Particle 9      82.82113      X
#
# ITERATION: 3 -> Global Best Value = 0.25515758734485183
#                                           atm_position  atm_value  \
# Particle 0    [6.657077091550538, -1.2804008564354694]  45.956102
# Particle 1   [-3.987847781458062, -1.2020868742279318]  17.347943
# Particle 2   [-0.23869211163363957, -1.21818310831034]   1.540944
# Particle 3     [0.1989751618471427, 4.072851839859396]  16.627713
# Particle 4     [-1.288763479112005, 1.894470615439448]    5.24993
# Particle 5   [-1.9751612672977679, -4.617507598716887]  25.222638
# Particle 6  [-1.7898733014624855, 0.41036913998854396]   3.372049
# Particle 7   [-0.6439454901411374, 0.9357862341981908]   1.290362
# Particle 8    [-7.619818848851259, -3.206934675382314]  68.346069
# Particle 9   [1.2636593442569843, -0.5005594245374159]   1.847395
#
#            personal_best  chief
# Particle 0     25.312908      X
# Particle 1     11.530877      X
# Particle 2      1.540944      X
# Particle 3     16.627713      X
# Particle 4       5.24993      X
# Particle 5     22.882113      X
# Particle 6      0.255158  CHIEF
# Particle 7      1.290362      X
# Particle 8     68.346069      X
# Particle 9      1.847395      X
#
# ITERATION: 4 -> Global Best Value = 0.25515758734485183
#                                           atm_position  atm_value  \
# Particle 0   [3.5726600264884016, -0.7637936876093366]   13.34728
# Particle 1   [-2.334217318889539, -0.8265807212865626]   6.131806
# Particle 2      [5.598956773353613, 5.067358933921193]  57.026444
# Particle 3     [-6.737266569522552, 6.470769080968049]  87.261613
# Particle 4  [-3.1649207585368107, -1.8836529797168575]  13.564872
# Particle 5   [-1.1889581287054178, -2.683267587752556]   8.613546
# Particle 6   [-1.171251749324659, 0.08650068608379274]   1.379313
# Particle 7     [1.984426244122894, -2.887396380086707]  12.275005
# Particle 8     [-9.063936191159154, 2.604294935961283]  88.937291
# Particle 9     [2.2270033539965124, 5.546696096087508]  35.725382
#
#            personal_best  chief
# Particle 0      13.34728      X
# Particle 1      6.131806      X
# Particle 2      1.540944      X
# Particle 3     16.627713      X
# Particle 4       5.24993      X
# Particle 5      8.613546      X
# Particle 6      0.255158  CHIEF
# Particle 7      1.290362      X
# Particle 8     68.346069      X
# Particle 9      1.847395      X
#
# ITERATION: 5 -> Global Best Value = 0.22148371685740842
#                                           atm_position  atm_value  \
# Particle 0    [1.080763102572825, -0.3651826054121481]   1.301407
# Particle 1   [-1.0131182472968023, -0.521464272616147]   1.298334
# Particle 2      [6.1893904012473335, 5.79175607300879]  71.852992
# Particle 3     [-7.503014671776445, 6.349004186677136]  96.605083
# Particle 4    [-3.2830005229953585, -2.46028346140819]  16.831087
# Particle 5  [-0.5712958303831515, -1.1310175821542738]    1.60558
# Particle 6   [-0.2707386540554608, -0.384947136705348]   0.221484
# Particle 7     [2.277430425122467, -3.388121450184609]  16.666056
# Particle 8     [-8.605383961739395, 3.446818187650816]  85.933189
# Particle 9      [2.187729719604142, 6.186177960600531]  43.054959
#
#            personal_best  chief
# Particle 0      1.301407      X
# Particle 1      1.298334      X
# Particle 2      1.540944      X
# Particle 3     16.627713      X
# Particle 4       5.24993      X
# Particle 5       1.60558      X
# Particle 6      0.221484  CHIEF
# Particle 7      1.290362      X
# Particle 8     68.346069      X
# Particle 9      1.847395      X
#
# ITERATION: 6 -> Global Best Value = 0.047879929028663094
#                                            atm_position  atm_value  \
# Particle 0  [-1.1356551241460626, -0.09305875683504233]   1.298372
# Particle 1  [0.17097023617651597, -0.26019623039433604]   0.096933
# Particle 2     [3.6194066180810314, 3.3487691550443333]  24.314359
# Particle 3     [-4.642015154122911, 3.6542203394780706]  34.901631
# Particle 4   [-2.0879951551644345, -1.6466761945810995]   7.071266
# Particle 5  [-0.03394519443624211, 0.21616579933779723]    0.04788
# Particle 6    [0.3596205126329779, -0.7149606126577466]   0.640496
# Particle 7    [1.2621678558595004, -2.2007664302063814]   6.436441
# Particle 8     [-5.261618223803424, 1.9458929693091451]  31.471126
# Particle 9     [1.1970067801684268, 3.5825144871693473]  14.267235
#
#            personal_best  chief
# Particle 0      1.298372      X
# Particle 1      0.096933      X
# Particle 2      1.540944      X
# Particle 3     16.627713      X
# Particle 4       5.24993      X
# Particle 5       0.04788  CHIEF
# Particle 6      0.221484      X
# Particle 7      1.290362      X
# Particle 8     31.471126      X
# Particle 9      1.847395      X
#
# ITERATION: 7 -> Global Best Value = 0.047879929028663094
#                                            atm_position  atm_value  \
# Particle 0    [-2.194084335421623, 0.23581949787537154]   4.869617
# Particle 1     [0.908123525701311, 0.13588431492364117]   0.843153
# Particle 2    [-3.0140820995179176, -3.550605823691972]  21.691493
# Particle 3     [3.4375604523907146, 0.5763563179066158]  12.149008
# Particle 4     [0.33057723868998146, 2.693173646199378]   7.362466
# Particle 5     [0.34220025072659443, 1.159194166382247]   1.460832
# Particle 6  [0.10198637432741403, -0.25557476574188015]    0.07572
# Particle 7    [-1.6092953083285204, 2.3131625360625945]   7.940552
# Particle 8     [-0.5813690848262691, 0.121116490443403]   0.352659
# Particle 9  [0.007869683136976446, -3.1326721432475146]   9.813697
#
#            personal_best  chief
# Particle 0      1.298372      X
# Particle 1      0.096933      X
# Particle 2      1.540944      X
# Particle 3     12.149008      X
# Particle 4       5.24993      X
# Particle 5       0.04788  CHIEF
# Particle 6       0.07572      X
# Particle 7      1.290362      X
# Particle 8      0.352659      X
# Particle 9      1.847395      X
#
# ITERATION: 8 -> Global Best Value = 0.011847308526694363
#                                            atm_position  atm_value  \
# Particle 0     [-2.523782066043993, 0.3483547332821759]   6.490827
# Particle 1    [1.1464543124391011, 0.27302465693460504]     1.3889
# Particle 2      [-6.62084661030561, -7.489401115891065]  99.926739
# Particle 3     [9.039500119704227, -1.5837267728690003]  84.220753
# Particle 4      [1.4399971517422785, 5.407653569723273]  31.316309
# Particle 5      [0.465432079622604, 1.4681467587003492]   2.372082
# Particle 6  [-0.08046269662208261, 0.07330117992909158]   0.011847
# Particle 7     [-3.2503930575375115, 4.948857204392498]  35.056243
# Particle 8      [2.703283274021351, -1.154755014766117]     8.6412
# Particle 9    [-0.3769882062625496, -6.842050125956156]   46.95577
#
#            personal_best  chief
# Particle 0      1.298372      X
# Particle 1      0.096933      X
# Particle 2      1.540944      X
# Particle 3     12.149008      X
# Particle 4       5.24993      X
# Particle 5       0.04788      X
# Particle 6      0.011847  CHIEF
# Particle 7      1.290362      X
# Particle 8      0.352659      X
# Particle 9      1.847395      X
#
# ITERATION: 9 -> Global Best Value = 0.011847308526694363
#                                            atm_position  atm_value  \
# Particle 0    [-0.6378246770320679, 0.1763149454736896]   0.437907
# Particle 1    [0.23812869067896503, 0.1775576734652226]   0.088232
# Particle 2     [-3.362269940027319, -3.607954106450909]  24.322192
# Particle 3     [5.041393409059492, -1.6067072429701745]  27.997156
# Particle 4     [0.8174418982136181, 2.6652297189429133]   7.771661
# Particle 5   [0.07045190589812661, 0.45581905711610426]   0.212734
# Particle 6   [-0.20817704628673026, 0.3035143418987718]   0.135459
# Particle 7    [-1.6175429673751878, 2.5153520189828362]   8.943441
# Particle 8      [2.516062838480094, -0.958555489185785]   7.249401
# Particle 9  [-0.32483413283122775, -3.3415965834101757]  11.271785
#
#            personal_best  chief
# Particle 0      0.437907      X
# Particle 1      0.088232      X
# Particle 2      1.540944      X
# Particle 3     12.149008      X
# Particle 4       5.24993      X
# Particle 5       0.04788      X
# Particle 6      0.011847  CHIEF
# Particle 7      1.290362      X
# Particle 8      0.352659      X
# Particle 9      1.847395      X
#
# ITERATION: 10 -> Global Best Value = 0.011847308526694363
#                                            atm_position atm_value  \
# Particle 0   [0.9764482262210901, 0.001529906333611386]  0.953453
# Particle 1   [-0.5658100959459914, 0.05571784812059255]  0.323246
# Particle 2      [0.726008805357528, 1.1093578036901812]  1.757764
# Particle 3  [-0.49872726081941465, -0.6834915624368385]   0.71589
# Particle 4   [-0.1430973371644234, -0.6407941943641227]  0.431094
# Particle 5  [-0.2881928058753405, -0.46045099071937023]   0.29507
# Particle 6  [-0.22709646063709635, 0.33761777829138534]  0.165559
# Particle 7   [0.36007553872396625, -0.5149098960237324]  0.394787
# Particle 8     [0.9399680144377762, -0.250617106360596]  0.946349
# Particle 9   [-0.12094967062519851, 0.9793884224448566]  0.973831
#
#            personal_best  chief
# Particle 0      0.437907      X
# Particle 1      0.088232      X
# Particle 2      1.540944      X
# Particle 3       0.71589      X
# Particle 4      0.431094      X
# Particle 5       0.04788      X
# Particle 6      0.011847  CHIEF
# Particle 7      0.394787      X
# Particle 8      0.352659      X
# Particle 9      0.973831      X
#
# ITERATION: 11 -> Global Best Value = 0.0017703738425929043
#                                              atm_position  atm_value  \
# Particle 0     [0.22622492935790095, 0.05946308290546461]   0.054714
# Particle 1     [-0.2145800800581023, 0.07838462361870352]   0.052189
# Particle 2         [2.36869721425788, 1.9668737353158114]   9.479319
# Particle 3       [-4.148422521330351, 0.3759985696052699]  17.350784
# Particle 4     [-0.7812737789482865, -2.5650862515033572]   7.190056
# Particle 5   [-0.22057740856847446, -0.26420076702565853]   0.118456
# Particle 6  [-0.04190414048515498, 0.0037969530933762985]    0.00177
# Particle 7       [1.5038569678227118, -2.314906424374371]   7.620378
# Particle 8       [-1.948571941027713, 0.7218887313561615]   4.318056
# Particle 9     [0.043876962698154276, 3.5093179928145033]  12.317238
#
#            personal_best  chief
# Particle 0      0.054714      X
# Particle 1      0.052189      X
# Particle 2      1.540944      X
# Particle 3       0.71589      X
# Particle 4      0.431094      X
# Particle 5       0.04788      X
# Particle 6       0.00177  CHIEF
# Particle 7      0.394787      X
# Particle 8      0.352659      X
# Particle 9      0.973831      X
#
# ITERATION: 12 -> Global Best Value = 0.0017703738425929043
#                                            atm_position atm_value  \
# Particle 0  [-0.39699017385561997, 0.07965837352346523]  0.163947
# Particle 1    [0.0944310946790301, 0.06697354415449444]  0.013403
# Particle 2   [0.8675441711324783, -0.31225381599949387]  0.850135
# Particle 3    [-2.724616280112568, 0.26252447113740884]  7.492453
# Particle 4    [-0.5245156918213645, -1.666737275706872]   3.05313
# Particle 5   [0.018750312215338794, 0.2971743737237259]  0.088664
# Particle 6     [0.08773048362120398, -0.22987762454523]   0.06054
# Particle 7    [0.9629963246186399, -1.5053952417064709]  3.193577
# Particle 8    [-2.3454337302949897, 0.7323263138156448]  6.037361
# Particle 9   [0.016028545308714864, 2.2813715233310914]  5.204913
#
#            personal_best  chief
# Particle 0      0.054714      X
# Particle 1      0.013403      X
# Particle 2      0.850135      X
# Particle 3       0.71589      X
# Particle 4      0.431094      X
# Particle 5       0.04788      X
# Particle 6       0.00177  CHIEF
# Particle 7      0.394787      X
# Particle 8      0.352659      X
# Particle 9      0.973831      X
#
# ITERATION: 13 -> Global Best Value = 0.001108591826042379
#                                               atm_position atm_value  \
# Particle 0    [-0.024729623299744652, 0.02229433913564395]  0.001109
# Particle 1     [0.21476926973350474, 0.014514268368093691]  0.046337
# Particle 2        [-0.8234454736005632, -1.68516737295662]  3.517852
# Particle 3       [2.1554302070974627, -0.8469002972024811]  5.363119
# Particle 4        [0.33678364482887924, 1.057539311261257]  1.231813
# Particle 5       [0.09635515822203639, 0.4110174935294777]   0.17822
# Particle 6  [-0.028963444975025704, -0.019529465897882486]   0.00122
# Particle 7       [-0.6633484232748446, 1.0113433040354285]  1.462846
# Particle 8      [0.5793185954453746, -0.32099447948251325]  0.438647
# Particle 9      [-0.1670125013625274, -1.3483348979505294]    1.8459
#
#            personal_best  chief
# Particle 0      0.001109  CHIEF
# Particle 1      0.013403      X
# Particle 2      0.850135      X
# Particle 3       0.71589      X
# Particle 4      0.431094      X
# Particle 5       0.04788      X
# Particle 6       0.00122      X
# Particle 7      0.394787      X
# Particle 8      0.352659      X
# Particle 9      0.973831      X
#
# ITERATION: 14 -> Global Best Value = 0.001108591826042379
#                                             atm_position  atm_value  \
# Particle 0  [0.23585276208936806, -0.017860484935830943]   0.055946
# Particle 1    [0.2758296123980556, -0.01949011802516263]   0.076462
# Particle 2     [-1.8776692143955593, -2.460140142832717]   9.577931
# Particle 3      [5.297425839008465, -1.5504435229568907]  30.466596
# Particle 4      [0.8926434976252507, 2.8166860390223283]   8.730533
# Particle 5    [0.13615093390437796, 0.45310965112028695]   0.223845
# Particle 6   [-0.11032555323852586, 0.13091134003840224]    0.02931
# Particle 7      [-1.7115670572711659, 2.635706694066652]   9.876412
# Particle 8      [2.533511801204269, -1.0141905536008315]   7.447265
# Particle 9    [-0.2824012507020898, -3.6901813937320727]  13.697189
#
#            personal_best  chief
# Particle 0      0.001109  CHIEF
# Particle 1      0.013403      X
# Particle 2      0.850135      X
# Particle 3       0.71589      X
# Particle 4      0.431094      X
# Particle 5       0.04788      X
# Particle 6       0.00122      X
# Particle 7      0.394787      X
# Particle 8      0.352659      X
# Particle 9      0.973831      X
#
# ITERATION: 15 -> Global Best Value = 0.001108591826042379
#                                           atm_position  atm_value  \
# Particle 0  [0.3854387192354477, -0.04091115194002888]   0.150237
# Particle 1  [0.2877181506186462, -0.03540433522202106]   0.084035
# Particle 2   [-2.329797768926254, -2.7096075285976102]  12.769931
# Particle 3    [6.798611748978443, -1.8863096239104484]  49.779286
# Particle 4      [1.159240760253792, 3.657149531190989]  14.718582
# Particle 5   [0.1432026135180314, 0.43970492028493663]   0.213847
# Particle 6  [-0.15674660435141965, 0.2200809602600005]   0.073005
# Particle 7     [-2.210238376907479, 3.412015605516082]  16.527004
# Particle 8    [3.546508404987098, -1.3630691515245341]  14.435679
# Particle 9  [-0.33637332464444714, -4.805617973376513]  23.207111
#
#            personal_best  chief
# Particle 0      0.001109  CHIEF
# Particle 1      0.013403      X
# Particle 2      0.850135      X
# Particle 3       0.71589      X
# Particle 4      0.431094      X
# Particle 5       0.04788      X
# Particle 6       0.00122      X
# Particle 7      0.394787      X
# Particle 8      0.352659      X
# Particle 9      0.973831      X
#
# ITERATION: 16 -> Global Best Value = 0.0005771854616956248
#                                               atm_position atm_value  \
# Particle 0   [-0.012639206462459307, 0.020431248657263992]  0.000577
# Particle 1     [0.019535042405119052, 0.06411394674223665]  0.004492
# Particle 2       [0.9767282093527587, 0.16556335113784915]  0.981409
# Particle 3      [-0.9382930965230978, -0.4126063052543998]  1.050638
# Particle 4     [-0.21125037503342492, -0.8027797663757448]  0.689082
# Particle 5     [-0.06595021324808287, 0.09192259751489723]  0.012799
# Particle 6  [-0.031197569143734644, 0.0026723038152601797]   0.00098
# Particle 7      [0.46361610666797226, -0.6798292558225336]  0.677108
# Particle 8       [-0.6195296132052639, 0.1792263081886214]  0.415939
# Particle 9      [-0.07813180833258315, 1.1870489298562044]   1.41519
#
#            personal_best  chief
# Particle 0      0.000577  CHIEF
# Particle 1      0.004492      X
# Particle 2      0.850135      X
# Particle 3       0.71589      X
# Particle 4      0.431094      X
# Particle 5      0.012799      X
# Particle 6       0.00098      X
# Particle 7      0.394787      X
# Particle 8      0.352659      X
# Particle 9      0.973831      X
#
# ITERATION: 17 -> Global Best Value = 0.0005771854616956248
#                                             atm_position  atm_value  \
# Particle 0    [-0.2912937544509942, 0.06337092907536901]   0.088868
# Particle 1     [-0.181293790115318, 0.11599009626736707]   0.046321
# Particle 2         [2.79584926807694, 1.713855187978161]  10.754073
# Particle 3     [-5.6044278205304705, 0.5655737820087491]  31.729485
# Particle 4    [-1.0319239297856266, -3.4521578513814166]  12.982261
# Particle 5  [-0.19065010552252526, -0.18063475612382424]   0.068976
# Particle 6   [0.06424331853810246, -0.14228269827659212]   0.024372
# Particle 7       [2.05358143029091, -3.1191228951716434]  13.946124
# Particle 8      [-3.256279950440106, 1.1448927258103518]  11.914138
# Particle 9      [0.09299091524285033, 4.730779019684098]  22.388917
#
#            personal_best  chief
# Particle 0      0.000577  CHIEF
# Particle 1      0.004492      X
# Particle 2      0.850135      X
# Particle 3       0.71589      X
# Particle 4      0.431094      X
# Particle 5      0.012799      X
# Particle 6       0.00098      X
# Particle 7      0.394787      X
# Particle 8      0.352659      X
# Particle 9      0.973831      X
#
# ITERATION: 18 -> Global Best Value = 0.0005771854616956248
#                                           atm_position  atm_value  \
# Particle 0  [-0.4239326849650993, 0.08381011920661799]   0.186743
# Particle 1    [-0.2799967550324193, 0.136462101819827]    0.09702
# Particle 2      [3.552239890072797, 2.375952769834943]   18.26356
# Particle 3     [-7.680064399416701, 1.038524238923343]  60.061922
# Particle 4    [-1.3946904737972525, -4.61307848972806]  23.225655
# Particle 5  [-0.244855693263113, -0.31727942314771546]   0.160621
# Particle 6  [0.11146620079653635, -0.2095649575784242]   0.056342
# Particle 7   [2.7511937130525346, -4.1915504494994575]  25.138162
# Particle 8     [-4.447864460561469, 1.581802108501536]  22.285596
# Particle 9    [0.17531934746850908, 6.278408993896848]  39.449156
#
#            personal_best  chief
# Particle 0      0.000577  CHIEF
# Particle 1      0.004492      X
# Particle 2      0.850135      X
# Particle 3       0.71589      X
# Particle 4      0.431094      X
# Particle 5      0.012799      X
# Particle 6       0.00098      X
# Particle 7      0.394787      X
# Particle 8      0.352659      X
# Particle 9      0.973831      X
#
# ITERATION: 19 -> Global Best Value = 0.00025928403654275133
#                                               atm_position atm_value  \
# Particle 0     [-0.06876776332210122, 0.02908046077771939]  0.005575
# Particle 1     [-0.03986286205375683, 0.04884099665589994]  0.003974
# Particle 2       [0.6909910573094118, 0.08748820255309919]  0.485123
# Particle 3      [-1.053006922781786, -0.13320197088807784]  1.126566
# Particle 4       [-0.2161759233924334, -0.748471565069126]  0.606942
# Particle 5   [-0.05967638024245253, -0.005074930584622328]  0.003587
# Particle 6  [-0.0010452510387402858, -0.01606833802260718]  0.000259
# Particle 7      [0.43745900013079764, -0.6537332775943252]  0.618738
# Particle 8      [-0.7689624875663004, 0.24320265410310737]  0.650451
# Particle 9      [-0.03238342421138349, 1.0815693263924047]  1.170841
#
#            personal_best  chief
# Particle 0      0.000577      X
# Particle 1      0.003974      X
# Particle 2      0.485123      X
# Particle 3       0.71589      X
# Particle 4      0.431094      X
# Particle 5      0.003587      X
# Particle 6      0.000259  CHIEF
# Particle 7      0.394787      X
# Particle 8      0.352659      X
# Particle 9      0.973831      X
#
# ITERATION: 20 -> Global Best Value = 0.00025928403654275133
#                                             atm_position  atm_value  \
# Particle 0  [0.20966166832073196, -0.028787558222730783]   0.044787
# Particle 1   [0.14496318300047356, -0.04047292684538781]   0.022652
# Particle 2    [-1.6101851756167185, -1.5590750113232872]   5.023411
# Particle 3      [4.045525592017366, -0.9090201747326727]  17.192595
# Particle 4      [0.7023263938152362, 2.2736491461361394]   5.662743
# Particle 5    [0.09522207010960074, 0.20872950912198296]   0.052635
# Particle 6   [-0.07980326732343393, 0.11937929566646471]    0.02062
# Particle 7     [-1.3720302692070185, 2.0991429667233694]   6.288868
# Particle 8      [2.139358975969058, -0.8069290450132869]   5.227991
# Particle 9   [-0.16524886152244558, -3.0304875716143727]   9.211162
#
#            personal_best  chief
# Particle 0      0.000577      X
# Particle 1      0.003974      X
# Particle 2      0.485123      X
# Particle 3       0.71589      X
# Particle 4      0.431094      X
# Particle 5      0.003587      X
# Particle 6      0.000259  CHIEF
# Particle 7      0.394787      X
# Particle 8      0.352659      X
# Particle 9      0.973831      X
#
# *** SEARCH IS OVER! ***
# C:\anaconda3\lib\site-packages\pandas\core\internals\blocks.py:938: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   arr_value = np.asarray(value)
# C:\anaconda3\lib\site-packages\pandas\core\internals\blocks.py:938: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   arr_value = np.asarray(value)
# C:\anaconda3\lib\site-packages\pandas\core\internals\blocks.py:938: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   arr_value = np.asarray(value)
# C:\anaconda3\lib\site-packages\pandas\core\internals\blocks.py:938: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   arr_value = np.asarray(value)
# C:\anaconda3\lib\site-packages\pandas\core\internals\blocks.py:938: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   arr_value = np.asarray(value)
# C:\anaconda3\lib\site-packages\pandas\core\internals\blocks.py:938: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   arr_value = np.asarray(value)
# C:\anaconda3\lib\site-packages\pandas\core\internals\blocks.py:938: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   arr_value = np.asarray(value)
# C:\anaconda3\lib\site-packages\pandas\core\internals\blocks.py:938: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   arr_value = np.asarray(value)
# C:\anaconda3\lib\site-packages\pandas\core\internals\blocks.py:938: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   arr_value = np.asarray(value)
# C:\anaconda3\lib\site-packages\pandas\core\internals\blocks.py:938: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   arr_value = np.asarray(value)
# C:\anaconda3\lib\site-packages\pandas\core\internals\blocks.py:938: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   arr_value = np.asarray(value)
# C:\anaconda3\lib\site-packages\pandas\core\internals\blocks.py:938: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   arr_value = np.asarray(value)
# C:\anaconda3\lib\site-packages\pandas\core\internals\blocks.py:938: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   arr_value = np.asarray(value)
# C:\anaconda3\lib\site-packages\pandas\core\internals\blocks.py:938: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   arr_value = np.asarray(value)
# C:\anaconda3\lib\site-packages\pandas\core\internals\blocks.py:938: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   arr_value = np.asarray(value)
# C:\anaconda3\lib\site-packages\pandas\core\internals\blocks.py:938: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   arr_value = np.asarray(value)
# C:\anaconda3\lib\site-packages\pandas\core\internals\blocks.py:938: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   arr_value = np.asarray(value)
# C:\anaconda3\lib\site-packages\pandas\core\internals\blocks.py:938: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   arr_value = np.asarray(value)
# C:\anaconda3\lib\site-packages\pandas\core\internals\blocks.py:938: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   arr_value = np.asarray(value)
# C:\anaconda3\lib\site-packages\pandas\core\internals\blocks.py:938: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   arr_value = np.asarray(value)
